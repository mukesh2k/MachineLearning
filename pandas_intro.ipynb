# %%
import pandas as pd
p=pd.DataFrame({"yes": [50, 100, 20, 235], 'No': [45, 54, 6, 7]},
             index=["asd", "asd", "asd", "asd"])
out=p.to_csv("hey.csv")

# %% [markdown]
# data frame is just a json file with json array

# %%
pd.Series([1, 2, 3, 4, 5], index=["sad", "sad", "sad", "sad", "sad"])
# Out:
# sad    1
# sad    2
# sad    3
# sad    4
# sad    5
# dtype: int64

# %% [markdown]
# series is a list but data frame is a table

# %%
filepath="melb_data.csv"
data=pd.read_csv(filepath) #specifying index column
print(data)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
data.head() #first n row
data.tail() #last n row
data.shape #number of rows and columns
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
data.iloc[1:4,1:2] # tells [{row index},{column index}] perfectly numric index will be perfect 0:4 -> 4
# Out:
#             Address
# 1   25 Bloomburg St
# 2      5 Charles St
# 3  40 Federation La

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
data.loc[0:2,["Address","Rooms","Type"]] # loc is used when column names are avaliable indexing not perfect 0:4 -> 5
# Out:
#            Address  Rooms Type
# 0     85 Turner St      2    h
# 1  25 Bloomburg St      2    h
# 2     5 Charles St      3    h

# %%
data.loc[(data["SellerG"] == 'Biggin') & (data["Rooms"]==2)]
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford         85 Turner St      2    h  1480000.0      S
# 1          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 9          Abbotsford        10 Valiant St      2    h  1097000.0      S
# 12         Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 13         Abbotsford        45 William St      2    h  1172500.0      S
# ...               ...                  ...    ...  ...        ...    ...
# 11979     Elsternwick     3/14 Sinclair St      2    u   834500.0      S
# 12141        Richmond      712/8 Howard St      2    u   927000.0      S
# 12549       Maidstone         19 Howard St      2    h   865000.0      S
# 12830        Richmond           29 Type St      2    h  1200000.0      S
# 13079  West Footscray         28 Tucker St      2    h   855000.0      S
#
#       SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
data.loc[data["SellerG"].isin(['Nelson'])]
# Out:
#            Suburb           Address  Rooms Type      Price Method SellerG  \
# 4      Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
# 6      Abbotsford      124 Yarra St      3    h  1876000.0      S  Nelson
# 7      Abbotsford     98 Charles St      2    h  1636000.0      S  Nelson
# 11     Abbotsford   40 Nicholson St      3    h  1350000.0     VB  Nelson
# 27     Abbotsford  48 Abbotsford St      3    h  1447500.0     PI  Nelson
# ...           ...               ...    ...  ...        ...    ...     ...
# 13525     Preston      61 Dundas St      3    h   910000.0     SP  Nelson
# 13534     Rosanna   179 Beverley Rd      3    h  1224000.0      S  Nelson
# 13535     Rosanna    30 Phillips Cr      4    h  1426000.0      S  Nelson
# 13563   Thornbury      201 Gooch St      3    h  1271000.0      S  Nelson
# 13567    Viewbank     149 Graham Rd      5    h  1316000.0     SP  Nelson
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
data["SellerG"].unique()
data["SellerG"].map(lambda p:p+" Person")

# data.apply(func,axis='columns')
data["SellerG"].value_counts()
# Out:
# Nelson                     1565
# Jellis                     1316
# hockingstuart              1167
# Barry                      1011
# Ray                         701
#                            ...
# WHITEFOX                      1
# Parkinson                     1
# hockingstuart/Advantage       1
# Private/Tiernan's             1
# Nicholls                      1
# Name: SellerG, Length: 268, dtype: int64

# %%
data.groupby("SellerG").SellerG.count()
# Out:
# SellerG
# @Realty                   2
# ASL                       4
# Abercromby's             21
# Ace                       2
# Alexkarbon               40
#                          ..
# hockingstuart/Village     1
# iOne                      1
# iProperty                 1
# iSell                    11
# iTRAK                    13
# Name: SellerG, Length: 268, dtype: int64

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
data.groupby("Type").Type.count()
data.Type.replace("h","y")
data.groupby("Type").Type.count()
data[data.Type.isnull()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.groupby("Type").Type.count()
# Out:
# Type
# h    9449
# t    1114
# u    3017
# Name: Type, dtype: int64

# %%
data.rename(columns={'Type':'type'})
data.rename(Type={0:'hey',1="hey1"}) #work only if index is defined
# Out:
#   File "<ipython-input-48-3e7db54a42f5>", line 2
#     data.rename(Type={0:'hey',1="hey1"})
#                 ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
data['ype']
# Out:
# 0        h
# 1        h
# 2        h
# 3        h
# 4        h
#         ..
# 13575    h
# 13576    h
# 13577    h
# 13578    h
# 13579    h
# Name: Type, Length: 13580, dtype: object
